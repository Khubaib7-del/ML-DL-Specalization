# %% [markdown]
# # Optional Lab: Overfitting
#
# ## Goals
# In this lab, you will explore:
# - The concepts of **underfitting**, **overfitting**, and **generalization**.
# - How regularization (tuning $\lambda$) affects model fit for both Linear and Logistic Regression.

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from plt_overfit import overfit_example
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# ## Overfitting Example
# Run the cell below to launch the interactive plot demonstrating overfitting and regularization controls.

# %%
plt.close('all')
ofit = overfit_example(regularize=True)
